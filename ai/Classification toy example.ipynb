# %% [markdown]
# # Classification: toy example
#
# In the following example, we will first consider a synthetic classification problem that is linearly separable. Easy... and then a second synthetic example which is not linearly separable.
#
# The input data is two-dimensional, so that we can visualize what is going on.

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

np.random.seed(42)

# %matplotlib inline
plt.style.use('bmh')

# Change the color map
mpl.rcParams['image.cmap'] = 'Paired_r'

def plot_boundary(clf, X, y):
    """Plot the boundary of a given classifier as well as the input data"""
    h = 0.02
    x_min, x_max = X[:,0].min() - 10 * h, X[:,0].max() + 10 * h
    y_min, y_max = X[:,1].min() - 10 * h, X[:,1].max() + 10 * h
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(5,5))
    plt.contourf(xx, yy, Z, alpha=0.30)
    plt.contour(xx, yy, Z, colors='k', linewidths=0.7)
    plt.scatter(X[:,0], X[:,1], c=y, edgecolors='k')
    
    
def make_data(n):
    k = int(n / 2)
    X1 = np.random.multivariate_normal([-1, -1], [[0.5, 0.4], [0.4, 0.7]], k)
    X2 = np.random.multivariate_normal([1, 1], [[1, -0.3], [-0.3, 0.5]], n-k)
    X = np.concatenate((X1, X2))
    y = np.zeros(len(X))
    y[k+1:] = 1
    return X, y

# %% [markdown]
# ## Data split: training and testing

# %%
X, y = make_data(n=800)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.5)
plt.figure(figsize=(6,6))
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, edgecolors='k')

# %% [markdown]
# # Question 1: k Nearest Neighbors
#
# - Use sklearn to implement a k-Nearest Neighbors classifier.
# - use the `plot_boundary` function to show the
# - Make the hyperparameter k vary. What do you observe ?
# - How can you compute the accuracy of the prediction on the test set ?

# %%
# Answer question 1 here !!

# %% [markdown]
# # Question 2: Logistic Regression
#
# - Use sklearn to implement a logistic regression classifier.
# - How is the decision boundary. Is it expected ?
# - Compute the accuracy score.

# %%
# Answer question 2 here !!

# %% [markdown]
# # Question 3: Support Vector Machines
#
# - Use sklearn to implement a SVM classifier with **linear kernel**
# - Use sklearn to implement a SVM classifier with **RBF kernel**
# - Can you play of the **soft-margin hyperparameter** ? What do you observe ?
# - Compare both methods

# %%
# Answer to question 3 here !

# %% [markdown]
# # Question 4: Randomized Forest
#
# - use sklearn to implement a randomized forest classifier.
# - What can you say about the decision boundary ? Is it expected ?
# - play on the hyperparameters: number of trees, their depths, etc.

# %%
# Answer question 4 here !

# %% [markdown]
# # The non linearly separable example
#
# The first examples were easy, the data was well behaved and it was easy to separate one from the other with a simple line. What is this is not possible any more. Let's see how different classifier performs on this new challenge.

# %%
def make_data2(n):
    def f(X):
        X = X.copy()
        X[:,0] -= 0.4
        X[:,1] += 0.2
        return 1.1 * X[:,0]**2 + 0.3 * X[:,1]**2 - 0.6 * X[:,0]*X[:,1]

    X = np.random.normal(size=(n, 2))
    Y = f(X) < 0.5
    X += np.random.normal(size=(n,2), scale=0.2)
    return X, Y

X, y = make_data2(n=800)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.5)
plt.figure(figsize=(6,6))
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, edgecolors='k')

# %% [markdown]
# # Question 5: Linear regression and Linear SVM
#
# - Implement a linear regression
# - Implement a linear SVM
# - What do you observe. It is expected ?

# %%
# Write code here !

# %% [markdown]
# # Question 6: classifiers with no geometric assumption
#
# - can you think about some classifiers with no geometric assumption ?
# - implement them and display the result and compute the accuracy score.

# %%
# Write code here !

# %% [markdown]
# # Question 6: the kernel trick
#
# - implement a SVM with different kernels: what do you observe ?
# - can you make a 3D plot in the new feature space ?

# %%
# Write code here
